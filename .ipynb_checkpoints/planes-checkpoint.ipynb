# %%
# GPU
import torch
import os
from PIL import Image
import shutil
from ultralytics import YOLO
import random
import xml.etree.ElementTree as ET
import cv2



# Suppress the specific FutureWarning
#warnings.filterwarnings("ignore", category=FutureWarning)
# Check if MPS (Mixed Precision Support) is available
print(torch.backends.mps.is_available())
# Out:
# True

# %%
def convert_xml_to_yolo(xml_file, img_width, img_height, class_mapping):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    yolo_lines = []

    for obj in root.findall('object'):
        class_name = obj.find('name').text
        if class_name in class_mapping:
            class_idx = class_mapping[class_name]
            bbox = obj.find('bndbox')
            x_min = float(bbox.find('xmin').text)
            y_min = float(bbox.find('ymin').text) 
            x_max = float(bbox.find('xmax').text) 
            y_max = float(bbox.find('ymax').text) 
                                                                    
            x_center = (x_min + x_max) / (2.0 * img_width)
            y_center = (y_min + y_max) / (2.0 * img_height)
            width = (x_max - x_min) / img_width
            height = (y_max - y_min) / img_height
            
            '''
            # Calculate YOLO coordinates (normalized)
            x_center = x_center / img_width
            y_center = y_center / img_height
            width = width / img_width
            height = height / img_height 
            '''

            yolo_line = f"{class_idx} {x_center} {y_center} {width} {height}\n"
            yolo_lines.append(yolo_line)

    return yolo_lines

# Directory containing XML annotation files
xml_dir = r'/Users/work/Data/Planes/archive/Lables'

# Output directory for YOLO format annotation files
output_dir = '/Users/work/Data/Planes/archive/Lables'

# Image width and height (replace with your values)
img_width = 800  
img_height = 800 

# Class mapping (replace with your class mapping)
class_mapping = {
    'A1' : 0, 'A2' : 1, 'A3' : 2, 'A4' : 3, 'A5' : 4, 'A6' : 5, 'A7' : 6,
    'A8' : 7, 'A9' : 8, 'A10' : 9, 'A11' : 10, 'A12' : 11, 'A13' : 12,
    'A14' : 13, 'A15' : 14, 'A16' : 15, 'A17' : 16, 'A18' : 17, 'A19' : 18
}

# Iterate through XML files in the directory
for xml_filename in os.listdir(xml_dir):
    if xml_filename.endswith('.xml'):
        xml_path = os.path.join(xml_dir, xml_filename)
        xml_name = xml_filename.replace('.xml', '') 
        print(f'/Users/work/Data/Planes/archive/Test/{xml_name}.jpg')
        if os.path.exists(f'/Users/work/Data/Planes/archive/Test/{xml_name}.jpg'):
            image = cv2.imread(f'/Users/work/Data/Planes/archive/Test/{xml_name}.jpg')
            img_height, img_width, _ = image.shape

        else:
            image = cv2.imread(f'/Users/work/Data/Planes/archive/Train/{xml_name}.jpg')
            img_height, img_width, _ = image.shape

        yolo_lines = convert_xml_to_yolo(xml_path, img_width, img_height, class_mapping)

        # Create a corresponding YOLO format file
        yolo_filename = os.path.splitext(xml_filename)[0] + '.txt'
        yolo_path = os.path.join(output_dir, yolo_filename)

        # Save the YOLO annotation lines to the output file
        with open(yolo_path, 'w') as yolo_file:
            yolo_file.writelines(yolo_lines)
# Out:
# /Users/work/Data/Planes/archive/Test/162.jpg
# [ WARN:0@790.346] global loadsave.cpp:248 findDecoder imread_('/Users/work/Data/Planes/archive/Train/162.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 64
#      62 else:
#      63     image = cv2.imread(f'/Users/work/Data/Planes/archive/Train/{xml_name}.jpg')
# ---> 64     img_height, img_width, _ = image.shape
#      66 yolo_lines = convert_xml_to_yolo(xml_path, img_width, img_height, class_mapping)
#      68 # Create a corresponding YOLO format file
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
split = r'/Users/work/Data/Planes/archive/ImageSets/Main/train.txt'
xml_source = r'/Users/work/Data/Planes/archive/Lables'
destination = r'/Users/work/Data/Planes/archive/Train'

with open(split, 'r') as f:
    for i in f:
        print(xml_source + r'/' +  i.replace('\n', '') + '.jpg')
        img =  xml_source + r'/' +  i.replace('\n', '') + '.txt'
        shutil.move(img, destination)

split = r'/Users/work/Data/Planes/archive/ImageSets/Main/test.txt'
destination = r'/Users/work/Data/Planes/archive/Test'

with open(split, 'r') as f:
    for i in f:
        print(xml_source + r'/' +  i.replace('\n', '') + '.jpg')
        img =  xml_source + r'/' +  i.replace('\n', '') + '.txt'
        shutil.move(img, destination)
# Out:
# /Users/work/Data/Planes/archive/Lables/1680.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/work/Data/Planes/archive/Lables/1680.txt' -> '/Users/work/Data/Planes/archive/Train/1680.txt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       7         print(xml_source + r'/' +  i.replace('\n', '') + '.jpg')
#       8         img =  xml_source + r'/' +  i.replace('\n', '') + '.txt'
# ----> 9         shutil.move(img, destination)
# ...

# %%
model = YOLO('/opt/homebrew/runs/detect/train18/weights/best.pt') # Buildu a new model from scratch

# %%
sound_file = '/Users/work/Documents/oven.mp3'

start_time = time.time()

model = YOLO('yolov8n.pt') # Nano model
model.to('mps')
model.train(data='config.yaml', epochs=5, device='mps')

end_time = time.time()

# Calculate the elapsed time
print()
print('Time:', (end_time - start_time) /  3600 ) 


dingpy.ding(path = '/Users/work/Documents/oven.mp3' )

# %%
# Define path to the image file
num = random.randint(0, 1000)

if os.path.exists(f'/Users/work/Data/Planes/archive/Train/{num}.jpg'):
    print('Train')
    source = f'/Users/work/Data/Planes/archive/Train/{num}.jpg'
else:
    print('test')
    source = f'/Users/work/Data/Planes/archive/Test/{num}.jpg'

# Make predictions and get the Results object
results = model.predict(source, save=True)

# Access the original image from the Results object


Image.open(results[0].save_dir + r'/' + str(num) + '.jpg')
# Out:
# image 1/1 /Users/work/Data/Planes/archive/Test/331.jpg: 640x640 12 A2s, 67.6ms
# Speed: 5.2ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /opt/homebrew/runs/detect/predict10
# test
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800>

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
